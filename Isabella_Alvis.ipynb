# %% [markdown]
# ![weblogo.png](data:image/png;base64,...)

# %% [markdown]
# # **PARTE 1 LIMPIEZA**
# ---

# %% [markdown]
# # **LIMPIEZA DE DATOS CON PYTHON**
# ---

# %% [markdown]
# Importamos los paquetes que vamos a usar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import  SimpleImputer

# %% [markdown]
# Cargamos los datos

# %%
url = 'https://raw.githubusercontent.com/LalaA29/Actividad-limpieza-datos/refs/heads/main/all_players.csv'
data=pd.read_csv(url)
print("Datos desde la URL cargados con éxito.")
# Out:
# Datos desde la URL cargados con éxito.
# <ipython-input-2-3cf913d6aafd>:2: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv(url)

# %% [markdown]
# Recordemos algunos métodos útiles de los dataframe de pandas

# %%
data.head()
# Out:
#    Unnamed: 0  Rank             Name  OVR  PAC  SHO  PAS  DRI  DEF  PHY  ...  \
# 0           0     1    Kylian Mbappé   91   97   90   80   92   36   78  ...
# 1           1     2            Rodri   91   66   80   86   84   87   85  ...
# 2           2     4   Erling Haaland   91   88   92   70   81   45   88  ...
# 3           3     5  Jude Bellingham   90   80   87   83   88   78   83  ...
# 4           4     7         Vini Jr.   90   95   84   81   91   29   69  ...
#
#     Nation            League             Team  \
# 0   France  LALIGA EA SPORTS      Real Madrid
# 1    Spain    Premier League  Manchester City
# 2   Norway    Premier League  Manchester City
# 3  England  LALIGA EA SPORTS      Real Madrid
# 4   Brazil  LALIGA EA SPORTS      Real Madrid
#
#                                           play style  \
# 0  Quick Step+, Acrobatic, Finesse Shot, Flair, R...
# 1  Tiki Taka+, Aerial, Bruiser, Long Ball Pass, P...
# 2  Acrobatic+, Bruiser, Power Header, Power Shot,...
# ...

# %% [markdown]
# Para ver una informacion general sobre los atributos del dataframe

# %% [markdown]
# Descripción de cada columna:
# -Unnamed: 0: Identificador único o índice del registro.
# -Rank: Posición del jugador en un ranking determinado.
# -Name: Nombre del jugador.
# -OVR: Valor general del jugador
# -PAC: Velocidad de carrera
# -SHO: Poder de tiro
# -PAS: Pase
# -DRI: Regate
# -DEF: Defensa
# -PHY: Físico
# -Acceleration: Aceleración del jugador.
# -Sprint Speed: Velocidad en sprint.
# -Positioning: Posicionamiento en el campo.
# -Finishing: Precisión en los tiros a puerta.
# -Shot Power: Poder en los tiros.
# -Long Shots: Tiros de larga distancia.
# -Volleys: Habilidad en tiros de volea.
# -Penalties: Precisión en penaltis.
# -Vision: Visión del juego
# -Crossing: Precisión en centros.
# -Free Kick Accuracy: Precisión en tiros libres.
# -Short Passing: Precisión en pases cortos.
# -Long Passing: Precisión en pases largos.
# -Dribbling: Habilidad de driblear a los oponentes.
# -Agility: Agilidad del jugador.
# -Balance: Equilibrio del jugador.
# -Reactions: Tiempo de reacción del jugador.
# -Ball Control: Control del balón.
# -Composure: Composición
# -Interceptions: Habilidad para interceptar el balón.
# -Heading Accuracy: Precisión en los cabezazos.
# -Def Awareness: Conciencia defensiva.
# -Standing Tackle: Efectividad en los tackles de pie.
# -Sliding Tackle: Efectividad en los tackles deslizantes.
# -Jumping: Capacidad de salto.
# -Stamina: Resistencia del jugador.
# -Strength: Fuerza física.
# -Aggression: Nivel de agresividad.
# -Position: Posición en el campo.
# -Weak foot: Habilidad con el pie menos hábil
# -Skill moves: Habilidad en movimientos técnicos
# -Preferred foot: Pie preferido
# -Height: Altura del jugador.
# -Weight: Peso del jugador.
# -Alternative positions: Otras posiciones en las que puede jugar el jugador.
# -Age: Edad del jugador.
# -Nation: Nacionalidad del jugador.
# -League: Liga en la que juega.
# -Team: Equipo en el que juega.
# -Play style: Estilo de juego del jugador.
# -URL: Enlace a más información del jugador.
# -GK Diving: Habilidad del portero en saltos.
# -GK Handling: Manejo del balón por el portero.
# -GK Kicking: Efectividad en los despejes del portero.
# -GK Positioning: Posicionamiento del portero.
# -GK Reflexes: Reflejos del portero.

# %% [markdown]
# Cambiar de nombre de las variables

# %%
data.rename(columns={'Survived': 'Sobrevivio o no?'}, inplace=True)
#Renombrar múltiples columnas:cambiar varios nombres de columnas al mismo tiempo:
#df.rename(columns={'Survived': 'Sobrevivio o no?', 'Pclass': 'En que clase viajaba'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      1453 non-null   object
#  1   state_code                 1453 non-null   object
#  2   num_colonies               1453 non-null   int64
#  3   max_colonies               1453 non-null   int64
#  4   lost_colonies              1453 non-null   int64
#  5   percent_lost               1453 non-null   int64
#  6   added_colonies             1453 non-null   int64
#  7   renovated_colonies         1453 non-null   int64
#  8   percent_renovated          1453 non-null   int64
#  9   quarter                    1453 non-null   int64
#  10  year                       1453 non-null   int64
#  11  varroa_mites               1453 non-null   float64
#  12  other_pests_and_parasites  1453 non-null   float64
# ...

# %% [markdown]
# Para cambiar el tipo de dato de una columna

# %%
data['Sprint Speed']=data['Sprint Speed'].astype(str)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17737 entries, 0 to 17736
# Data columns (total 57 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             17737 non-null  int64
#  1   Rank                   17737 non-null  int64
#  2   Name                   17737 non-null  object
#  3   OVR                    17737 non-null  int64
#  4   PAC                    17737 non-null  int64
#  5   SHO                    17737 non-null  int64
#  6   PAS                    17737 non-null  int64
#  7   DRI                    17737 non-null  int64
#  8   DEF                    17737 non-null  int64
#  9   PHY                    17737 non-null  int64
#  10  Acceleration           17737 non-null  int64
#  11  Sprint Speed           17737 non-null  object
#  12  Positioning            17737 non-null  object
#  13  Finishing              17737 non-null  object
# ...

# %%
data['Sprint Speed']=data['Sprint Speed'].astype(int)

# %% [markdown]
# Para obtener una descrpcion estadistica de las columnas numericas

# %%
data.describe()
# Out:
#          Unnamed: 0          Rank           OVR           PAC           SHO  \
# count  17737.000000  17737.000000  17737.000000  17737.000000  17737.000000
# mean    8868.000000   8503.317021     66.796245     68.237921     54.846197
# std     5120.375198   5109.915335      7.030997     10.587756     13.858698
# min        0.000000      1.000000     47.000000     29.000000     20.000000
# 25%     4434.000000   4260.000000     62.000000     62.000000     46.000000
# 50%     8868.000000   7937.000000     67.000000     69.000000     57.000000
# 75%    13302.000000  13135.000000     71.000000     75.000000     65.000000
# max    17736.000000  17717.000000     91.000000     97.000000     93.000000
#
#                 PAS           DRI           DEF           PHY  Acceleration  \
# count  17737.000000  17737.000000  17737.000000  17737.000000  17737.000000
# mean      59.152506     64.205728     51.222473     65.420590     64.814343
# ...

# %% [markdown]
# Para obtener una descripcion de las categoricas

# %%
data.describe(include=['O'])
# Out:
#           Name Positioning Finishing Long Shots Volleys Crossing  \
# count    17737       17737     17737      17737   17737    17737
# unique   17608          93        94         86      88       87
# top     Danilo          58        60         60      48       60
# freq         4         570       500        522     431      593
#
#        Free Kick Accuracy  Curve Dribbling Interceptions  ... Position  \
# count               17737  17737     17737         17737  ...    17737
# unique                 87     87        90            85  ...       12
# top                    42     58        65            64  ...       CB
# freq                  491    460       734           553  ...     3185
#
#        Preferred foot         Height        Weight Alternative positions  \
# count           17737          17737         17737                  9778
# unique              2             56            60                   215
# ...

# %% [markdown]
# Para ver el tamaño del dataset

# %%
data.shape
# Out:
# (17737, 57)

# %% [markdown]
# ## **COMPROBACION DE OUTLIERS**

# %% [markdown]
# De forma visual

# %%
num_cols=data.select_dtypes(include='number').columns

for col in num_cols:
  plt.figure(figsize=(17,1))
  sns.boxplot(data=data[num_cols], x=col)
# Out:
# <ipython-input-11-77c43ab28d5e>:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(17,1))

# %% [markdown]
# Numericamente

# %%
#Nº de Outliers usando rango IQR
num_cols=data.select_dtypes(include='number').columns
outliers={}

for col in num_cols:
  Q1 = np.percentile(data[col], 25)
  Q3 = np.percentile(data[col], 75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  outliers[col]= (data[col] > upper_bound).sum() + (data[col]< lower_bound).sum()

print(outliers)
# Out:
# {'Unnamed: 0': 0, 'Rank': 0, 'OVR': 200, 'PAC': 346, 'SHO': 0, 'PAS': 148, 'DRI': 479, 'DEF': 0, 'PHY': 107, 'Acceleration': 632, 'Sprint Speed': 596, 'Shot Power': 6, 'Penalties': 5, 'Vision': 34, 'Short Passing': 1673, 'Long Passing': 352, 'Agility': 278, 'Balance': 329, 'Reactions': 328, 'Ball Control': 2036, 'Composure': 489, 'Jumping': 88, 'Stamina': 1370, 'Strength': 201, 'Aggression': 13, 'Weak foot': 6923, 'Skill moves': 54, 'Age': 37, 'GK Diving': 0, 'GK Handling': 0, 'GK Kicking': 0, 'GK Positioning': 0, 'GK Reflexes': 0}

# %%
#Nº de Outliers usando 3 std
outliers={}
for col in num_cols:
  mean=data[col].mean()
  std=data[col].std()

  outliers[col] = (data[col] > (mean + 3 *std)).sum() + (data[col] < (mean - 3 *std)).sum()

print(outliers)
# Out:
# {'Unnamed: 0': 0, 'Rank': 0, 'OVR': 43, 'PAC': 170, 'SHO': 0, 'PAS': 39, 'DRI': 120, 'DEF': 0, 'PHY': 50, 'Acceleration': 115, 'Sprint Speed': 128, 'Shot Power': 0, 'Penalties': 0, 'Vision': 0, 'Short Passing': 125, 'Long Passing': 0, 'Agility': 0, 'Balance': 11, 'Reactions': 73, 'Ball Control': 0, 'Composure': 89, 'Jumping': 23, 'Stamina': 0, 'Strength': 5, 'Aggression': 0, 'Weak foot': 305, 'Skill moves': 54, 'Age': 37, 'GK Diving': 1, 'GK Handling': 3, 'GK Kicking': 7, 'GK Positioning': 1, 'GK Reflexes': 1}

# %%
import seaborn as sns
sns.histplot(data['Penalties'])
# Out:
# <Axes: xlabel='Penalties', ylabel='Count'>

# %% [markdown]
# Veamos ahora los diferentes metodos de trabajar con nulos

# %%
data.isna().sum()
# Out:
# Unnamed: 0                   0
# Rank                         0
# Name                         0
# OVR                          0
# PAC                          0
# SHO                          0
# PAS                          0
# DRI                          0
# DEF                          0
# PHY                          0
# Acceleration                 0
# Sprint Speed                 0
# Positioning                  0
# Finishing                    0
# Shot Power                   0
# Long Shots                   0
# Volleys                      0
# Penalties                    0
# Vision                       0
# Crossing                     0
# Free Kick Accuracy           0
# Short Passing                0
# Long Passing                 0
# Curve                        0
# Dribbling                    0
# Agility                      0
# Balance                      0
# Reactions                    0
# Ball Control                 0
# Composure                    0
# ...

# %% [markdown]
# Veamos ahora los diferentes metodos de trabajar con nulos en porcentajes %

# %%
data.isna().sum() / len(data)
# Out:
# Unnamed: 0               0.000000
# Rank                     0.000000
# Name                     0.000000
# OVR                      0.000000
# PAC                      0.000000
# SHO                      0.000000
# PAS                      0.000000
# DRI                      0.000000
# DEF                      0.000000
# PHY                      0.000000
# Acceleration             0.000000
# Sprint Speed             0.000000
# Positioning              0.000000
# Finishing                0.000000
# Shot Power               0.000000
# Long Shots               0.000000
# Volleys                  0.000000
# Penalties                0.000000
# Vision                   0.000000
# Crossing                 0.000000
# Free Kick Accuracy       0.000000
# Short Passing            0.000000
# Long Passing             0.000000
# Curve                    0.000000
# Dribbling                0.000000
# Agility                  0.000000
# Balance                  0.000000
# ...

# %% [markdown]
# Eliminando los nulos

# %%
data.drop('Sprint Speed',axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17737 entries, 0 to 17736
# Data columns (total 56 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             17737 non-null  int64
#  1   Rank                   17737 non-null  int64
#  2   Name                   17737 non-null  object
#  3   OVR                    17737 non-null  int64
#  4   PAC                    17737 non-null  int64
#  5   SHO                    17737 non-null  int64
#  6   PAS                    17737 non-null  int64
#  7   DRI                    17737 non-null  int64
#  8   DEF                    17737 non-null  int64
#  9   PHY                    17737 non-null  int64
#  10  Acceleration           17737 non-null  int64
#  11  Positioning            17737 non-null  object
#  12  Finishing              17737 non-null  object
#  13  Shot Power             17737 non-null  int64
# ...

# %% [markdown]
# Imputando valores

# %%
sns.histplot(data['Finishing'])
# Out:
# <Axes: xlabel='Finishing', ylabel='Count'>
